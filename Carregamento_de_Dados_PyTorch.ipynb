# %%
import torch
from torch import nn
from torch import optim

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn import metrics
from sklearn.preprocessing import StandardScaler

import pandas as pd
import numpy as np
import time
import os


import matplotlib.pyplot as plt
# %matplotlib inline

# Configurando hiperparâmetros.
args = {
    'epoch_num': 200,     # Número de épocas.
    'lr': 5e-5,           # Taxa de aprendizado.
    'weight_decay': 5e-4, # Penalidade L2 (Regularização).
    'num_workers': 3,     # Número de threads do dataloader.
    'batch_size': 20,     # Tamanho do batch.
}

if torch.cuda.is_available():
    args['device'] = torch.device('cuda')
else:
    args['device'] = torch.device('cpu')

print(args['device'])
# Out:
# cuda

# %% [markdown]
# ### Baixando o dataset
#
# Fonte: https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset

# %%
! wget https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
! unzip Bike-Sharing-Dataset.zip
# Out:
# --2024-05-29 20:00:57--  https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘Bike-Sharing-Dataset.zip’
#
# Bike-Sharing-Datase     [   <=>              ] 273.43K   423KB/s    in 0.6s
#
# 2024-05-29 20:00:58 (423 KB/s) - ‘Bike-Sharing-Dataset.zip’ saved [279992]
#
# Archive:  Bike-Sharing-Dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv

# %% [markdown]
# ### Visualizando os dados

# %%
df = pd.read_csv('hour.csv')
print(len(df))
df.head()
# Out:
# 17379
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Train/Test split
torch.manual_seed(1)
indices = torch.randperm(len(df)).tolist()

train_size = int(0.8*len(df))
df_train = df.iloc[indices[:train_size]]
df_test  = df.iloc[indices[train_size:]]

print(len(df_train), len(df_test))
display(df_test.head())

df_train.to_csv('bike_train.csv',index=False)
df_test.to_csv('bike_test.csv',index=False)
# !ls
# Out:
# 13903 3476
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 12663    12664  2012-06-16       2   1     6  20        0        6
# 1801      1802  2011-03-20       1   0     3  18        0        0
# 16567    16568  2012-11-28       4   1    11   1        0        3
# 8817      8818  2012-01-08       1   1     1   5        0        0
# 2608      2609  2011-04-23       2   0     4  14        0        6
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 12663           0           2  0.66  0.6212  0.47     0.1940     123
# 1801            0           1  0.38  0.3939  0.40     0.3582      58
# 16567           1           2  0.26  0.2576  0.75     0.2239       0
# 8817            0           2  0.32  0.3333  0.49     0.1045       0
# 2608            0           1  0.58  0.5455  0.78     0.3582     182
#
#        registered  cnt
# 12663         229  352
# 1801           98  156
# 16567          12   12
# 8817            2    2
# 2608          209  391
# Bike-Sharing-Dataset.zip  bike_test.csv  bike_train.csv  day.csv  hour.csv  Readme.txt	sample_data

# %%
class Bike(Dataset):
  def __init__(self, csv_path, scaler_feat=None, scaler_label=None):

    self.dados = pd.read_csv(csv_path).to_numpy()

  def __getitem__(self, idx):

    sample = self.dados[idx][2:14]
    label  = self.dados[idx][-1:]

    # converte para tensor
    sample = torch.from_numpy(sample.astype(np.float32))
    label  = torch.from_numpy(label.astype(np.float32))

    return sample, label

  def __len__(self):
    return len(self.dados)

# %%
dataset = Bike('bike_train.csv')
dado, rotulo = dataset[0]
print(rotulo)
print(dado)
# Out:
# tensor([373.])
# tensor([ 4.0000,  1.0000, 11.0000, 19.0000,  0.0000,  4.0000,  1.0000,  1.0000,
#          0.3800,  0.3939,  0.2700,  0.3582])

# %% [markdown]
# ### Construindo conjuntos de treino e teste

# %%
train_set = Bike('bike_train.csv')
test_set  = Bike('bike_test.csv')

print('Tamanho do treino: ' + str(len(train_set)) + ' amostras')
print('Tamanho do teste: ' + str(len(test_set)) + ' amostras')
# Out:
# Tamanho do treino: 13903 amostras
# Tamanho do teste: 3476 amostras

# %% [markdown]
# ## Dataloader

# %%
# Criando dataloader
train_loader = DataLoader(train_set,
                          args['batch_size'],
                          num_workers=args['num_workers'],
                          shuffle=True)
test_loader = DataLoader(test_set,
                         args['batch_size'],
                         num_workers=args['num_workers'],
                         shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# O objeto retornado é um **iterador**, podendo ser utilizado para iterar em loops mas não suportando indexação.

# %%
for batch in test_loader:

  dado, rotulo = batch
  print('## Dimensionalidade do batch ##')
  print(dado.size(), rotulo.size())

  break
# Out:
# ## Dimensionalidade do batch ##
# torch.Size([20, 12]) torch.Size([20, 1])

# %%
class MLP(nn.Module):

  def __init__(self, input_size, hidden_size, out_size):
    super(MLP, self).__init__()

    self.features = nn.Sequential(
          nn.Linear(input_size, hidden_size),
          nn.ReLU(),
          nn.Linear(hidden_size, hidden_size),
          nn.ReLU(),
    )

    self.classifier = nn.Sequential(
        nn.Linear(hidden_size, out_size),
        nn.ReLU(),
    )

  def forward(self, X):

    hidden = self.features(X)
    output = self.classifier(hidden)

    return output

input_size  = train_set[0][0].size(0)
hidden_size = 128
out_size    = 1

net = MLP(input_size, hidden_size, out_size).to(args['device'])
print(net)
# Out:
# MLP(
#   (features): Sequential(
#     (0): Linear(in_features=12, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=1, bias=True)
#     (1): ReLU()
#   )
# )

# %%
criterion = nn.L1Loss().to(args['device'])

optimizer = optim.Adam(net.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

# %%
def train(train_loader, net, epoch):

  # Training mode
  net.train()

  start = time.time()

  epoch_loss  = []
  for batch in train_loader:

    dado, rotulo = batch

    # Cast do dado na GPU
    dado = dado.to(args['device'])
    rotulo = rotulo.to(args['device'])

    # Forward
    ypred = net(dado)
    loss = criterion(ypred, rotulo)
    epoch_loss.append(loss.cpu().data)

    # Backpropagation
    loss.backward()
    optimizer.step()

  epoch_loss = np.asarray(epoch_loss)

  end = time.time()
  print('#################### Train ####################')
  print('Epoch %d, Loss: %.4f +/- %.4f, Time: %.2f' % (epoch, epoch_loss.mean(), epoch_loss.std(), end-start))

  return epoch_loss.mean()

# %%
def validate(test_loader, net, epoch):

  # Evaluation mode
  net.eval()

  start = time.time()

  epoch_loss  = []

  with torch.no_grad():
    for batch in test_loader:

      dado, rotulo = batch

      # Cast do dado na GPU
      dado = dado.to(args['device'])
      rotulo = rotulo.to(args['device'])

      # Forward
      ypred = net(dado)
      loss = criterion(ypred, rotulo)
      epoch_loss.append(loss.cpu().data)

  epoch_loss = np.asarray(epoch_loss)

  end = time.time()
  print('********** Validate **********')
  print('Epoch %d, Loss: %.4f +/- %.4f, Time: %.2f\n' % (epoch, epoch_loss.mean(), epoch_loss.std(), end-start))

  return epoch_loss.mean()

# %%
train_losses, test_losses = [], []
for epoch in range(args['epoch_num']):

  # Train
  train_losses.append(train(train_loader, net, epoch))

  # Validate
  test_losses.append(validate(test_loader, net, epoch))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# #################### Train ####################
# Epoch 0, Loss: 164.3138 +/- 42.0975, Time: 5.73
# ********** Validate **********
# Epoch 0, Loss: 125.7965 +/- 30.3890, Time: 0.78
#
# #################### Train ####################
# Epoch 1, Loss: 130.6107 +/- 25.6430, Time: 5.93
# ********** Validate **********
# Epoch 1, Loss: 126.6351 +/- 24.3811, Time: 0.73
#
# #################### Train ####################
# Epoch 2, Loss: 122.8896 +/- 30.2196, Time: 2.22
# ********** Validate **********
# Epoch 2, Loss: 125.2943 +/- 31.5335, Time: 0.45
#
# #################### Train ####################
# Epoch 3, Loss: 120.4436 +/- 31.0856, Time: 2.21
# ********** Validate **********
# Epoch 3, Loss: 117.2516 +/- 26.3097, Time: 0.45
#
# #################### Train ####################
# Epoch 4, Loss: 118.8116 +/- 24.6739, Time: 2.23
# ********** Validate **********
# Epoch 4, Loss: 114.5222 +/- 28.4489, Time: 0.45
#
# #################### Train ####################
# Epoch 5, Loss: 118.3620 +/- 31.7777, Time: 2.52
# ********** Validate **********
# Epoch 5, Loss: 115.1214 +/- 29.4287, Time: 0.72
#
# #################### Train ####################
# Epoch 6, Loss: 115.6204 +/- 27.2290, Time: 2.81
# ********** Validate **********
# Epoch 6, Loss: 114.4763 +/- 26.8682, Time: 0.47
#
# #################### Train ####################
# Epoch 7, Loss: 113.9728 +/- 27.5469, Time: 2.29
# ********** Validate **********
# Epoch 7, Loss: 111.4903 +/- 28.6823, Time: 0.44
#
# #################### Train ####################
# Epoch 8, Loss: 111.6958 +/- 25.9598, Time: 2.30
# ********** Validate **********
# Epoch 8, Loss: 108.0189 +/- 26.1602, Time: 0.43
#
# #################### Train ####################
# Epoch 9, Loss: 107.8523 +/- 28.5930, Time: 2.36
# ********** Validate **********
# Epoch 9, Loss: 104.4426 +/- 26.1499, Time: 0.50
#
# #################### Train ####################
# Epoch 10, Loss: 104.0013 +/- 24.9873, Time: 3.03
# ********** Validate **********
# Epoch 10, Loss: 100.6575 +/- 26.5714, Time: 0.54
#
# #################### Train ####################
# Epoch 11, Loss: 99.7791 +/- 24.9244, Time: 2.28
# ********** Validate **********
# Epoch 11, Loss: 95.8762 +/- 24.1800, Time: 0.46
#
# #################### Train ####################
# Epoch 12, Loss: 96.6181 +/- 24.3921, Time: 2.28
# ********** Validate **********
# Epoch 12, Loss: 95.3268 +/- 23.4922, Time: 0.46
#
# #################### Train ####################
# Epoch 13, Loss: 96.5652 +/- 24.5964, Time: 2.33
# ********** Validate **********
# Epoch 13, Loss: 93.7601 +/- 22.9797, Time: 0.44
#
# #################### Train ####################
# Epoch 14, Loss: 94.7762 +/- 23.8114, Time: 2.54
# ********** Validate **********
# Epoch 14, Loss: 90.6446 +/- 22.7672, Time: 0.65
#
# #################### Train ####################
# Epoch 15, Loss: 92.5352 +/- 22.5312, Time: 2.53
# ********** Validate **********
# Epoch 15, Loss: 90.2427 +/- 24.1546, Time: 0.43
#
# #################### Train ####################
# Epoch 16, Loss: 92.1613 +/- 23.4260, Time: 2.26
# ********** Validate **********
# Epoch 16, Loss: 91.4790 +/- 24.8746, Time: 0.47
#
# #################### Train ####################
# Epoch 17, Loss: 92.0641 +/- 22.9335, Time: 2.32
# ********** Validate **********
# Epoch 17, Loss: 91.0208 +/- 24.2056, Time: 0.47
#
# #################### Train ####################
# Epoch 18, Loss: 91.8287 +/- 23.8059, Time: 2.26
# ********** Validate **********
# Epoch 18, Loss: 89.5614 +/- 23.9393, Time: 0.62
#
# #################### Train ####################
# Epoch 19, Loss: 90.2647 +/- 22.5071, Time: 3.04
# ********** Validate **********
# Epoch 19, Loss: 86.8868 +/- 21.9028, Time: 0.47
#
# #################### Train ####################
# Epoch 20, Loss: 89.8782 +/- 22.6900, Time: 2.29
# ********** Validate **********
# Epoch 20, Loss: 87.4174 +/- 21.4498, Time: 0.44
#
# #################### Train ####################
# Epoch 21, Loss: 89.1638 +/- 23.4761, Time: 2.34
# ********** Validate **********
# Epoch 21, Loss: 85.8003 +/- 22.3733, Time: 0.44
#
# #################### Train ####################
# Epoch 22, Loss: 88.6031 +/- 22.9051, Time: 2.30
# ********** Validate **********
# Epoch 22, Loss: 85.4528 +/- 23.1586, Time: 0.45
#
# #################### Train ####################
# Epoch 23, Loss: 88.3556 +/- 23.2039, Time: 2.69
# ********** Validate **********
# Epoch 23, Loss: 86.9407 +/- 24.3840, Time: 0.69
#
# #################### Train ####################
# Epoch 24, Loss: 87.2508 +/- 23.6855, Time: 2.51
# ********** Validate **********
# Epoch 24, Loss: 87.4662 +/- 24.9258, Time: 0.45
#
# #################### Train ####################
# Epoch 25, Loss: 86.6316 +/- 23.6898, Time: 2.38
# ********** Validate **********
# Epoch 25, Loss: 87.2847 +/- 24.7103, Time: 0.47
#
# #################### Train ####################
# Epoch 26, Loss: 85.6851 +/- 21.7451, Time: 2.28
# ********** Validate **********
# Epoch 26, Loss: 85.6722 +/- 23.9596, Time: 0.47
#
# #################### Train ####################
# Epoch 27, Loss: 84.5536 +/- 22.2833, Time: 2.59
# ********** Validate **********
# Epoch 27, Loss: 83.8421 +/- 23.7815, Time: 0.76
#
# #################### Train ####################
# Epoch 28, Loss: 84.9101 +/- 22.4519, Time: 3.50
# ********** Validate **********
# Epoch 28, Loss: 85.9929 +/- 24.1830, Time: 0.66
#
# #################### Train ####################
# Epoch 29, Loss: 85.3920 +/- 22.6777, Time: 2.26
# ********** Validate **********
# Epoch 29, Loss: 86.5721 +/- 24.9212, Time: 0.51
#
# #################### Train ####################
# Epoch 30, Loss: 84.6966 +/- 22.0110, Time: 2.28
# ********** Validate **********
# Epoch 30, Loss: 84.8617 +/- 24.6853, Time: 0.43
#
# #################### Train ####################
# Epoch 31, Loss: 84.4923 +/- 20.8040, Time: 2.25
# ********** Validate **********
# Epoch 31, Loss: 84.0180 +/- 24.2058, Time: 0.43
#
# #################### Train ####################
# Epoch 32, Loss: 84.8859 +/- 22.2025, Time: 2.91
# ********** Validate **********
# Epoch 32, Loss: 81.7820 +/- 23.9310, Time: 0.70
#
# #################### Train ####################
# Epoch 33, Loss: 85.5708 +/- 23.3168, Time: 2.47
# ********** Validate **********
# Epoch 33, Loss: 80.4363 +/- 21.4974, Time: 0.46
#
# #################### Train ####################
# Epoch 34, Loss: 85.3634 +/- 23.0856, Time: 2.30
# ********** Validate **********
# Epoch 34, Loss: 86.7377 +/- 20.4070, Time: 0.44
#
# #################### Train ####################
# Epoch 35, Loss: 83.6698 +/- 23.3299, Time: 2.92
# ********** Validate **********
# Epoch 35, Loss: 83.1451 +/- 20.6867, Time: 0.44
#
# #################### Train ####################
# Epoch 36, Loss: 85.6631 +/- 24.4125, Time: 2.53
# ********** Validate **********
# Epoch 36, Loss: 82.8422 +/- 24.1974, Time: 0.69
#
# #################### Train ####################
# Epoch 37, Loss: 83.2437 +/- 21.2996, Time: 2.92
# ********** Validate **********
# Epoch 37, Loss: 81.7773 +/- 24.2379, Time: 0.45
#
# #################### Train ####################
# Epoch 38, Loss: 84.7959 +/- 22.4155, Time: 2.29
# ********** Validate **********
# Epoch 38, Loss: 85.3593 +/- 20.2608, Time: 0.43
#
# #################### Train ####################
# Epoch 39, Loss: 83.0986 +/- 24.1056, Time: 2.29
# ********** Validate **********
# Epoch 39, Loss: 77.9774 +/- 21.6435, Time: 0.44
#
# #################### Train ####################
# Epoch 40, Loss: 83.4088 +/- 21.1212, Time: 2.33
# ********** Validate **********
# Epoch 40, Loss: 84.5304 +/- 25.2292, Time: 0.47
#
# #################### Train ####################
# Epoch 41, Loss: 83.6298 +/- 22.0077, Time: 2.91
# ********** Validate **********
# Epoch 41, Loss: 81.3540 +/- 20.2061, Time: 0.58
#
# #################### Train ####################
# Epoch 42, Loss: 82.2472 +/- 24.0806, Time: 2.28
# ********** Validate **********
# Epoch 42, Loss: 78.0422 +/- 20.5900, Time: 0.46
#
# #################### Train ####################
# Epoch 43, Loss: 82.9364 +/- 21.8694, Time: 2.32
# ********** Validate **********
# Epoch 43, Loss: 83.5093 +/- 24.9830, Time: 0.46
#
# #################### Train ####################
# Epoch 44, Loss: 82.4050 +/- 21.6970, Time: 2.26
# ********** Validate **********
# Epoch 44, Loss: 77.9464 +/- 20.3873, Time: 0.48
#
# #################### Train ####################
# Epoch 45, Loss: 80.6119 +/- 23.3012, Time: 2.56
# ********** Validate **********
# Epoch 45, Loss: 77.6269 +/- 20.5074, Time: 0.70
#
# #################### Train ####################
# Epoch 46, Loss: 81.1102 +/- 21.1410, Time: 2.49
# ********** Validate **********
# Epoch 46, Loss: 80.2376 +/- 24.0662, Time: 0.46
#
# #################### Train ####################
# Epoch 47, Loss: 80.1854 +/- 22.8747, Time: 2.24
# ********** Validate **********
# Epoch 47, Loss: 75.8004 +/- 20.7305, Time: 0.45
#
# #################### Train ####################
# Epoch 48, Loss: 78.9919 +/- 22.3850, Time: 2.28
# ********** Validate **********
# Epoch 48, Loss: 78.8147 +/- 19.8986, Time: 0.46
#
# #################### Train ####################
# Epoch 49, Loss: 79.2713 +/- 21.5859, Time: 2.23
# ********** Validate **********
# Epoch 49, Loss: 77.7330 +/- 23.6875, Time: 0.57
#
# #################### Train ####################
# Epoch 50, Loss: 78.6200 +/- 20.7650, Time: 3.10
# ********** Validate **********
# Epoch 50, Loss: 75.5848 +/- 22.7363, Time: 0.55
#
# #################### Train ####################
# Epoch 51, Loss: 79.3114 +/- 22.4057, Time: 2.26
# ********** Validate **********
# Epoch 51, Loss: 79.5544 +/- 19.8953, Time: 0.45
#
# #################### Train ####################
# Epoch 52, Loss: 77.9221 +/- 21.8998, Time: 2.27
# ********** Validate **********
# Epoch 52, Loss: 73.3936 +/- 21.2449, Time: 0.46
#
# #################### Train ####################
# Epoch 53, Loss: 77.3971 +/- 21.1969, Time: 2.27
# ********** Validate **********
# Epoch 53, Loss: 77.2189 +/- 23.3758, Time: 0.44
#
# #################### Train ####################
# Epoch 54, Loss: 77.5422 +/- 21.3147, Time: 2.48
# ********** Validate **********
# Epoch 54, Loss: 73.6856 +/- 20.2093, Time: 0.65
#
# #################### Train ####################
# Epoch 55, Loss: 76.2380 +/- 20.7145, Time: 2.98
# ********** Validate **********
# Epoch 55, Loss: 75.7738 +/- 19.7867, Time: 0.42
#
# #################### Train ####################
# Epoch 56, Loss: 76.0522 +/- 20.7065, Time: 2.25
# ********** Validate **********
# Epoch 56, Loss: 74.3406 +/- 22.4361, Time: 0.44
#
# #################### Train ####################
# Epoch 57, Loss: 74.5430 +/- 20.9586, Time: 2.24
# ********** Validate **********
# Epoch 57, Loss: 73.6881 +/- 21.8857, Time: 0.47
#
# #################### Train ####################
# Epoch 58, Loss: 74.0126 +/- 21.1534, Time: 2.25
# ********** Validate **********
# Epoch 58, Loss: 70.7120 +/- 20.6743, Time: 0.47
#
# #################### Train ####################
# Epoch 59, Loss: 73.0820 +/- 20.1837, Time: 2.78
# ********** Validate **********
# Epoch 59, Loss: 72.5333 +/- 19.5262, Time: 0.67
#
# #################### Train ####################
# Epoch 60, Loss: 72.0908 +/- 20.4945, Time: 2.29
# ********** Validate **********
# Epoch 60, Loss: 70.0234 +/- 19.9362, Time: 0.45
#
# #################### Train ####################
# Epoch 61, Loss: 71.5289 +/- 19.1597, Time: 2.31
# ********** Validate **********
# Epoch 61, Loss: 69.9016 +/- 19.4743, Time: 0.44
#
# #################### Train ####################
# Epoch 62, Loss: 70.7717 +/- 19.4962, Time: 2.25
# ********** Validate **********
# Epoch 62, Loss: 68.2260 +/- 19.9612, Time: 0.49
#
# #################### Train ####################
# Epoch 63, Loss: 70.3615 +/- 21.0302, Time: 2.45
# ********** Validate **********
# Epoch 63, Loss: 68.4590 +/- 20.8937, Time: 0.67
#
# #################### Train ####################
# Epoch 64, Loss: 70.6008 +/- 20.0549, Time: 2.97
# ********** Validate **********
# Epoch 64, Loss: 68.6764 +/- 20.7643, Time: 0.45
#
# #################### Train ####################
# Epoch 65, Loss: 70.1006 +/- 19.9579, Time: 2.35
# ********** Validate **********
# Epoch 65, Loss: 69.4288 +/- 21.3365, Time: 0.44
#
# #################### Train ####################
# Epoch 66, Loss: 70.0048 +/- 19.8679, Time: 2.27
# ********** Validate **********
# Epoch 66, Loss: 69.3679 +/- 20.9825, Time: 0.46
#
# #################### Train ####################
# Epoch 67, Loss: 69.0481 +/- 19.6633, Time: 2.29
# ********** Validate **********
# Epoch 67, Loss: 69.5413 +/- 21.8604, Time: 0.47
#
# #################### Train ####################
# Epoch 68, Loss: 70.0146 +/- 18.8528, Time: 2.99
# ********** Validate **********
# Epoch 68, Loss: 69.4637 +/- 21.0582, Time: 0.58
#
# #################### Train ####################
# Epoch 69, Loss: 68.8509 +/- 19.3677, Time: 2.30
# ********** Validate **********
# Epoch 69, Loss: 68.4587 +/- 20.9775, Time: 0.46
#
# #################### Train ####################
# Epoch 70, Loss: 70.6373 +/- 19.4080, Time: 2.25
# ********** Validate **********
# Epoch 70, Loss: 65.6735 +/- 20.0213, Time: 0.46
#
# #################### Train ####################
# Epoch 71, Loss: 69.8536 +/- 19.5094, Time: 2.33
# ********** Validate **********
# Epoch 71, Loss: 67.5449 +/- 18.7302, Time: 0.48
#
# #################### Train ####################
# Epoch 72, Loss: 68.1723 +/- 17.9762, Time: 2.50
# ********** Validate **********
# Epoch 72, Loss: 70.7860 +/- 19.0399, Time: 0.67
#
# #################### Train ####################
# Epoch 73, Loss: 67.9671 +/- 18.9552, Time: 2.84
# ********** Validate **********
# Epoch 73, Loss: 64.6307 +/- 18.7978, Time: 0.46
#
# #################### Train ####################
# Epoch 74, Loss: 68.0549 +/- 19.5313, Time: 2.30
# ********** Validate **********
# Epoch 74, Loss: 65.8837 +/- 20.1956, Time: 0.45
#
# #################### Train ####################
# Epoch 75, Loss: 67.4189 +/- 17.7699, Time: 2.33
# ********** Validate **********
# Epoch 75, Loss: 69.1025 +/- 20.8426, Time: 0.45
#
# #################### Train ####################
# Epoch 76, Loss: 68.0306 +/- 18.6047, Time: 2.28
# ********** Validate **********
# Epoch 76, Loss: 63.6376 +/- 18.4918, Time: 0.47
#
# #################### Train ####################
# Epoch 77, Loss: 65.6836 +/- 18.6248, Time: 2.93
# ********** Validate **********
# Epoch 77, Loss: 65.0481 +/- 18.3666, Time: 0.55
#
# #################### Train ####################
# Epoch 78, Loss: 65.3402 +/- 18.4685, Time: 2.27
# ********** Validate **********
# Epoch 78, Loss: 63.6231 +/- 17.9044, Time: 0.48
#
# #################### Train ####################
# Epoch 79, Loss: 65.2411 +/- 17.4394, Time: 2.33
# ********** Validate **********
# Epoch 79, Loss: 63.2361 +/- 18.8271, Time: 0.46
#
# #################### Train ####################
# Epoch 80, Loss: 65.4856 +/- 18.4060, Time: 2.28
# ********** Validate **********
# Epoch 80, Loss: 62.8817 +/- 18.4710, Time: 0.43
#
# #################### Train ####################
# Epoch 81, Loss: 64.6785 +/- 17.1681, Time: 2.60
# ********** Validate **********
# Epoch 81, Loss: 64.7964 +/- 19.2338, Time: 0.70
#
# #################### Train ####################
# Epoch 82, Loss: 64.4653 +/- 17.7037, Time: 2.80
# ********** Validate **********
# Epoch 82, Loss: 60.7130 +/- 18.1485, Time: 0.44
#
# #################### Train ####################
# Epoch 83, Loss: 64.8450 +/- 18.7931, Time: 2.27
# ********** Validate **********
# Epoch 83, Loss: 65.1423 +/- 16.9028, Time: 0.46
#
# #################### Train ####################
# Epoch 84, Loss: 63.9158 +/- 17.8471, Time: 2.28
# ********** Validate **********
# Epoch 84, Loss: 64.5466 +/- 17.7871, Time: 0.45
#
# #################### Train ####################
# Epoch 85, Loss: 64.6208 +/- 18.1522, Time: 2.27
# ********** Validate **********
# Epoch 85, Loss: 64.3017 +/- 18.0407, Time: 0.46
#
# #################### Train ####################
# Epoch 86, Loss: 63.2924 +/- 16.7393, Time: 2.91
# ********** Validate **********
# Epoch 86, Loss: 61.4485 +/- 18.7892, Time: 0.58
#
# #################### Train ####################
# Epoch 87, Loss: 63.9444 +/- 18.1383, Time: 2.32
# ********** Validate **********
# Epoch 87, Loss: 62.1672 +/- 16.9086, Time: 0.46
#
# #################### Train ####################
# Epoch 88, Loss: 63.1141 +/- 17.9322, Time: 2.29
# ********** Validate **********
# Epoch 88, Loss: 63.9479 +/- 16.3754, Time: 0.45
#
# #################### Train ####################
# Epoch 89, Loss: 63.6969 +/- 16.7613, Time: 2.36
# ********** Validate **********
# Epoch 89, Loss: 61.7642 +/- 18.8163, Time: 0.45
#
# #################### Train ####################
# Epoch 90, Loss: 62.4301 +/- 16.2032, Time: 2.55
# ********** Validate **********
# Epoch 90, Loss: 62.8836 +/- 16.8459, Time: 0.70
#
# #################### Train ####################
# Epoch 91, Loss: 62.6776 +/- 16.8593, Time: 2.55
# ********** Validate **********
# Epoch 91, Loss: 62.0594 +/- 16.8528, Time: 0.45
#
# #################### Train ####################
# Epoch 92, Loss: 62.2561 +/- 17.1062, Time: 2.34
# ********** Validate **********
# Epoch 92, Loss: 61.2687 +/- 16.2952, Time: 0.47
#
# #################### Train ####################
# Epoch 93, Loss: 62.8630 +/- 16.8458, Time: 2.45
# ********** Validate **********
# Epoch 93, Loss: 59.2630 +/- 16.7521, Time: 0.49
#
# #################### Train ####################
# Epoch 94, Loss: 61.4300 +/- 16.0868, Time: 2.42
# ********** Validate **********
# Epoch 94, Loss: 61.0868 +/- 18.3925, Time: 0.67
#
# #################### Train ####################
# Epoch 95, Loss: 62.5624 +/- 17.3272, Time: 2.98
# ********** Validate **********
# Epoch 95, Loss: 62.2880 +/- 15.9943, Time: 0.49
#
# #################### Train ####################
# Epoch 96, Loss: 61.0586 +/- 16.1833, Time: 2.44
# ********** Validate **********
# Epoch 96, Loss: 61.2296 +/- 16.9789, Time: 0.49
#
# #################### Train ####################
# Epoch 97, Loss: 60.8185 +/- 16.3076, Time: 2.59
# ********** Validate **********
# Epoch 97, Loss: 60.7460 +/- 16.9396, Time: 0.49
#
# #################### Train ####################
# Epoch 98, Loss: 60.1394 +/- 15.3680, Time: 2.93
# ********** Validate **********
# Epoch 98, Loss: 58.3407 +/- 16.8986, Time: 0.81
#
# #################### Train ####################
# Epoch 99, Loss: 60.1265 +/- 16.4843, Time: 3.20
# ********** Validate **********
# Epoch 99, Loss: 58.6156 +/- 16.1469, Time: 0.47
#
# #################### Train ####################
# Epoch 100, Loss: 59.4462 +/- 15.8835, Time: 2.35
# ********** Validate **********
# Epoch 100, Loss: 60.1306 +/- 16.2959, Time: 0.49
#
# #################### Train ####################
# Epoch 101, Loss: 59.8459 +/- 15.8497, Time: 2.43
# ********** Validate **********
# Epoch 101, Loss: 59.1451 +/- 16.6375, Time: 0.50
#
# #################### Train ####################
# Epoch 102, Loss: 58.8912 +/- 15.3145, Time: 2.34
# ********** Validate **********
# Epoch 102, Loss: 57.8143 +/- 16.8760, Time: 0.47
#
# #################### Train ####################
# Epoch 103, Loss: 58.2966 +/- 15.7128, Time: 3.11
# ********** Validate **********
# Epoch 103, Loss: 58.3309 +/- 16.4758, Time: 0.59
#
# #################### Train ####################
# Epoch 104, Loss: 57.9228 +/- 15.1625, Time: 2.42
# ********** Validate **********
# Epoch 104, Loss: 57.8139 +/- 16.7584, Time: 0.49
#
# #################### Train ####################
# Epoch 105, Loss: 57.9067 +/- 16.1193, Time: 2.36
# ********** Validate **********
# Epoch 105, Loss: 57.7210 +/- 16.9210, Time: 0.49
#
# #################### Train ####################
# Epoch 106, Loss: 57.6767 +/- 17.2451, Time: 2.36
# ********** Validate **********
# Epoch 106, Loss: 57.8418 +/- 16.4189, Time: 0.49
#
# #################### Train ####################
# Epoch 107, Loss: 57.4432 +/- 15.0696, Time: 2.88
# ********** Validate **********
# Epoch 107, Loss: 57.9594 +/- 16.0429, Time: 0.70
#
# #################### Train ####################
# Epoch 108, Loss: 57.0606 +/- 16.5863, Time: 2.51
# ********** Validate **********
# Epoch 108, Loss: 57.6400 +/- 16.5732, Time: 0.48
#
# #################### Train ####################
# Epoch 109, Loss: 56.8298 +/- 14.8829, Time: 2.36
# ********** Validate **********
# Epoch 109, Loss: 57.7498 +/- 16.5751, Time: 0.45
#
# #################### Train ####################
# Epoch 110, Loss: 56.8773 +/- 15.7147, Time: 2.34
# ********** Validate **********
# Epoch 110, Loss: 57.6766 +/- 16.6714, Time: 0.46
#
# #################### Train ####################
# Epoch 111, Loss: 56.9298 +/- 15.2390, Time: 2.57
# ********** Validate **********
# Epoch 111, Loss: 57.2166 +/- 16.4682, Time: 0.69
#
# #################### Train ####################
# Epoch 112, Loss: 56.8513 +/- 14.4460, Time: 3.08
# ********** Validate **********
# Epoch 112, Loss: 58.1205 +/- 16.1277, Time: 0.49
#
# #################### Train ####################
# Epoch 113, Loss: 56.6827 +/- 15.4138, Time: 2.34
# ********** Validate **********
# Epoch 113, Loss: 57.6620 +/- 16.3987, Time: 0.46
#
# #################### Train ####################
# Epoch 114, Loss: 57.3011 +/- 15.4665, Time: 2.36
# ********** Validate **********
# Epoch 114, Loss: 58.2625 +/- 16.4297, Time: 0.46
#
# #################### Train ####################
# Epoch 115, Loss: 57.0649 +/- 15.3026, Time: 2.33
# ********** Validate **********
# Epoch 115, Loss: 60.1499 +/- 16.2733, Time: 0.46
#
# #################### Train ####################
# Epoch 116, Loss: 57.2987 +/- 15.6280, Time: 2.88
# ********** Validate **********
# Epoch 116, Loss: 58.4304 +/- 16.2314, Time: 0.60
#
# #################### Train ####################
# Epoch 117, Loss: 56.8986 +/- 15.8002, Time: 2.27
# ********** Validate **********
# Epoch 117, Loss: 57.6523 +/- 16.0814, Time: 0.45
#
# #################### Train ####################
# Epoch 118, Loss: 57.8131 +/- 15.4223, Time: 2.31
# ********** Validate **********
# Epoch 118, Loss: 57.8868 +/- 16.2576, Time: 0.46
#
# #################### Train ####################
# Epoch 119, Loss: 57.1853 +/- 16.0947, Time: 2.40
# ********** Validate **********
# Epoch 119, Loss: 57.6773 +/- 16.5473, Time: 0.46
#
# #################### Train ####################
# Epoch 120, Loss: 56.9533 +/- 15.4169, Time: 2.80
# ********** Validate **********
# Epoch 120, Loss: 57.4087 +/- 16.7799, Time: 0.70
#
# #################### Train ####################
# Epoch 121, Loss: 56.6885 +/- 15.1919, Time: 2.56
# ********** Validate **********
# Epoch 121, Loss: 58.8330 +/- 16.5633, Time: 0.48
#
# #################### Train ####################
# Epoch 122, Loss: 56.4394 +/- 15.4565, Time: 2.39
# ********** Validate **********
# Epoch 122, Loss: 58.5041 +/- 16.2532, Time: 0.47
#
# #################### Train ####################
# Epoch 123, Loss: 55.9999 +/- 15.3207, Time: 2.34
# ********** Validate **********
# Epoch 123, Loss: 56.4858 +/- 15.9794, Time: 0.46
#
# #################### Train ####################
# Epoch 124, Loss: 55.7556 +/- 14.5045, Time: 2.58
# ********** Validate **********
# Epoch 124, Loss: 56.6784 +/- 15.7487, Time: 0.68
#
# #################### Train ####################
# Epoch 125, Loss: 55.9549 +/- 15.3322, Time: 3.05
# ********** Validate **********
# Epoch 125, Loss: 56.8297 +/- 16.0238, Time: 0.46
#
# #################### Train ####################
# Epoch 126, Loss: 55.3317 +/- 15.0266, Time: 2.40
# ********** Validate **********
# Epoch 126, Loss: 55.8191 +/- 15.9411, Time: 0.47
#
# #################### Train ####################
# Epoch 127, Loss: 55.7417 +/- 14.6356, Time: 2.40
# ********** Validate **********
# Epoch 127, Loss: 56.9888 +/- 15.8866, Time: 0.48
#
# #################### Train ####################
# Epoch 128, Loss: 55.5732 +/- 15.6622, Time: 2.43
# ********** Validate **********
# Epoch 128, Loss: 56.3275 +/- 15.3700, Time: 0.45
#
# #################### Train ####################
# Epoch 129, Loss: 55.1509 +/- 14.8230, Time: 3.04
# ********** Validate **********
# Epoch 129, Loss: 55.2031 +/- 15.6285, Time: 0.59
#
# #################### Train ####################
# Epoch 130, Loss: 55.2303 +/- 14.3219, Time: 2.37
# ********** Validate **********
# Epoch 130, Loss: 57.1088 +/- 15.6910, Time: 0.48
#
# #################### Train ####################
# Epoch 131, Loss: 55.6674 +/- 14.6921, Time: 2.39
# ********** Validate **********
# Epoch 131, Loss: 55.9480 +/- 16.0470, Time: 0.47
#
# #################### Train ####################
# Epoch 132, Loss: 55.5704 +/- 15.5005, Time: 2.43
# ********** Validate **********
# Epoch 132, Loss: 55.7072 +/- 15.5801, Time: 0.48
#
# #################### Train ####################
# Epoch 133, Loss: 55.7128 +/- 14.1033, Time: 2.78
# ********** Validate **********
# Epoch 133, Loss: 56.8397 +/- 16.1256, Time: 0.72
#
# #################### Train ####################
# Epoch 134, Loss: 55.7391 +/- 14.9695, Time: 2.48
# ********** Validate **********
# Epoch 134, Loss: 55.5709 +/- 15.7248, Time: 0.48
#
# #################### Train ####################
# Epoch 135, Loss: 55.6845 +/- 15.1505, Time: 2.35
# ********** Validate **********
# Epoch 135, Loss: 56.3297 +/- 16.1775, Time: 0.46
#
# #################### Train ####################
# Epoch 136, Loss: 54.5254 +/- 14.7673, Time: 2.31
# ********** Validate **********
# Epoch 136, Loss: 55.4463 +/- 15.9777, Time: 0.46
#
# #################### Train ####################
# Epoch 137, Loss: 54.6535 +/- 14.9673, Time: 2.50
# ********** Validate **********
# Epoch 137, Loss: 56.5690 +/- 15.4008, Time: 0.69
#
# #################### Train ####################
# Epoch 138, Loss: 54.7303 +/- 14.4615, Time: 2.98
# ********** Validate **********
# Epoch 138, Loss: 58.0701 +/- 15.7897, Time: 0.48
#
# #################### Train ####################
# Epoch 139, Loss: 54.2349 +/- 14.0550, Time: 2.32
# ********** Validate **********
# Epoch 139, Loss: 55.6921 +/- 15.4733, Time: 0.47
#
# #################### Train ####################
# Epoch 140, Loss: 53.4333 +/- 14.5704, Time: 2.33
# ********** Validate **********
# Epoch 140, Loss: 55.0949 +/- 15.5299, Time: 0.46
#
# #################### Train ####################
# Epoch 141, Loss: 53.1114 +/- 14.3105, Time: 2.37
# ********** Validate **********
# Epoch 141, Loss: 56.0164 +/- 15.2680, Time: 0.47
#
# #################### Train ####################
# Epoch 142, Loss: 53.4733 +/- 14.3552, Time: 3.00
# ********** Validate **********
# Epoch 142, Loss: 54.5097 +/- 15.3630, Time: 0.59
#
# #################### Train ####################
# Epoch 143, Loss: 53.5204 +/- 14.5999, Time: 2.27
# ********** Validate **********
# Epoch 143, Loss: 56.0631 +/- 15.5029, Time: 0.49
#
# #################### Train ####################
# Epoch 144, Loss: 54.1829 +/- 14.8952, Time: 2.30
# ********** Validate **********
# Epoch 144, Loss: 59.0998 +/- 15.7740, Time: 0.45
#
# #################### Train ####################
# Epoch 145, Loss: 54.0079 +/- 14.4647, Time: 2.33
# ********** Validate **********
# Epoch 145, Loss: 56.4942 +/- 15.5452, Time: 0.46
#
# #################### Train ####################
# Epoch 146, Loss: 53.5332 +/- 14.6568, Time: 2.58
# ********** Validate **********
# Epoch 146, Loss: 55.6446 +/- 15.5342, Time: 0.68
#
# #################### Train ####################
# Epoch 147, Loss: 53.3659 +/- 14.9659, Time: 2.47
# ********** Validate **********
# Epoch 147, Loss: 56.1923 +/- 15.2454, Time: 0.45
#
# #################### Train ####################
# Epoch 148, Loss: 53.3575 +/- 14.2492, Time: 2.31
# ********** Validate **********
# Epoch 148, Loss: 54.2169 +/- 15.5275, Time: 0.47
#
# #################### Train ####################
# Epoch 149, Loss: 54.0625 +/- 14.9765, Time: 2.29
# ********** Validate **********
# Epoch 149, Loss: 54.1703 +/- 15.4252, Time: 0.45
#
# #################### Train ####################
# Epoch 150, Loss: 53.6903 +/- 14.6236, Time: 2.34
# ********** Validate **********
# Epoch 150, Loss: 56.0876 +/- 15.7458, Time: 0.66
#
# #################### Train ####################
# Epoch 151, Loss: 52.8474 +/- 13.9795, Time: 3.16
# ********** Validate **********
# Epoch 151, Loss: 56.0212 +/- 15.2668, Time: 0.60
#
# #################### Train ####################
# Epoch 152, Loss: 53.6592 +/- 15.1112, Time: 2.30
# ********** Validate **********
# Epoch 152, Loss: 53.4382 +/- 15.4495, Time: 0.46
#
# #################### Train ####################
# Epoch 153, Loss: 52.9159 +/- 14.6614, Time: 2.34
# ********** Validate **********
# Epoch 153, Loss: 56.1034 +/- 15.2140, Time: 0.45
#
# #################### Train ####################
# Epoch 154, Loss: 52.9787 +/- 14.4746, Time: 2.28
# ********** Validate **********
# Epoch 154, Loss: 54.9109 +/- 15.2829, Time: 0.46
#
# #################### Train ####################
# Epoch 155, Loss: 53.1846 +/- 13.9000, Time: 2.54
# ********** Validate **********
# Epoch 155, Loss: 53.8167 +/- 15.4741, Time: 0.72
#
# #################### Train ####################
# Epoch 156, Loss: 52.9430 +/- 13.9713, Time: 2.61
# ********** Validate **********
# Epoch 156, Loss: 55.6605 +/- 15.6142, Time: 0.47
#
# #################### Train ####################
# Epoch 157, Loss: 52.3534 +/- 14.8772, Time: 2.34
# ********** Validate **********
# Epoch 157, Loss: 53.9189 +/- 15.1761, Time: 0.46
#
# #################### Train ####################
# Epoch 158, Loss: 52.8328 +/- 13.3207, Time: 2.32
# ********** Validate **********
# Epoch 158, Loss: 52.9774 +/- 15.0463, Time: 0.47
#
# #################### Train ####################
# Epoch 159, Loss: 52.2182 +/- 14.5269, Time: 2.41
# ********** Validate **********
# Epoch 159, Loss: 55.1216 +/- 14.6659, Time: 0.73
#
# #################### Train ####################
# Epoch 160, Loss: 52.5510 +/- 14.2961, Time: 3.13
# ********** Validate **********
# Epoch 160, Loss: 55.2806 +/- 15.0094, Time: 0.47
#
# #################### Train ####################
# Epoch 161, Loss: 53.1618 +/- 14.1713, Time: 2.35
# ********** Validate **********
# Epoch 161, Loss: 52.4054 +/- 14.8905, Time: 0.51
#
# #################### Train ####################
# Epoch 162, Loss: 52.9436 +/- 14.5482, Time: 2.30
# ********** Validate **********
# Epoch 162, Loss: 54.4205 +/- 15.3281, Time: 0.46
#
# #################### Train ####################
# Epoch 163, Loss: 53.0656 +/- 15.1348, Time: 2.27
# ********** Validate **********
# Epoch 163, Loss: 54.5287 +/- 15.1949, Time: 0.45
#
# #################### Train ####################
# Epoch 164, Loss: 53.1370 +/- 14.5926, Time: 3.24
# ********** Validate **********
# Epoch 164, Loss: 54.4963 +/- 15.5751, Time: 0.58
#
# #################### Train ####################
# Epoch 165, Loss: 53.0266 +/- 14.0121, Time: 2.24
# ********** Validate **********
# Epoch 165, Loss: 57.3788 +/- 15.1548, Time: 0.48
#
# #################### Train ####################
# Epoch 166, Loss: 53.4720 +/- 14.9995, Time: 2.50
# ********** Validate **********
# Epoch 166, Loss: 55.1822 +/- 15.4257, Time: 0.71
#
# #################### Train ####################
# Epoch 167, Loss: 53.1395 +/- 14.1348, Time: 2.99
# ********** Validate **********
# Epoch 167, Loss: 55.9911 +/- 15.4036, Time: 0.47
#
# #################### Train ####################
# Epoch 168, Loss: 53.4294 +/- 13.8670, Time: 3.10
# ********** Validate **********
# Epoch 168, Loss: 56.6880 +/- 15.6372, Time: 0.58
#
# #################### Train ####################
# Epoch 169, Loss: 53.3295 +/- 14.2609, Time: 2.29
# ********** Validate **********
# Epoch 169, Loss: 57.1348 +/- 14.8862, Time: 0.46
#
# #################### Train ####################
# Epoch 170, Loss: 53.2129 +/- 14.7447, Time: 2.29
# ********** Validate **********
# Epoch 170, Loss: 54.0068 +/- 15.3467, Time: 0.47
#
# #################### Train ####################
# Epoch 171, Loss: 52.4236 +/- 14.4523, Time: 2.42
# ********** Validate **********
# Epoch 171, Loss: 55.6297 +/- 15.3926, Time: 0.48
#
# #################### Train ####################
# Epoch 172, Loss: 51.3972 +/- 13.9459, Time: 2.68
# ********** Validate **********
# Epoch 172, Loss: 53.9858 +/- 15.5952, Time: 0.74
#
# #################### Train ####################
# Epoch 173, Loss: 52.3639 +/- 13.9323, Time: 2.43
# ********** Validate **********
# Epoch 173, Loss: 53.9839 +/- 14.7114, Time: 0.50
#
# #################### Train ####################
# Epoch 174, Loss: 51.7784 +/- 14.2187, Time: 2.31
# ********** Validate **********
# Epoch 174, Loss: 55.4430 +/- 16.2013, Time: 0.48
#
# #################### Train ####################
# Epoch 175, Loss: 51.4076 +/- 13.4885, Time: 2.36
# ********** Validate **********
# Epoch 175, Loss: 54.0748 +/- 14.9690, Time: 0.47
#
# #################### Train ####################
# Epoch 176, Loss: 51.3373 +/- 13.8905, Time: 2.61
# ********** Validate **********
# Epoch 176, Loss: 53.1924 +/- 15.4709, Time: 0.71
#
# #################### Train ####################
# Epoch 177, Loss: 51.6043 +/- 14.0372, Time: 3.14
# ********** Validate **********
# Epoch 177, Loss: 53.9751 +/- 15.3887, Time: 0.48
#
# #################### Train ####################
# Epoch 178, Loss: 50.9166 +/- 12.9820, Time: 2.36
# ********** Validate **********
# Epoch 178, Loss: 52.8337 +/- 15.6181, Time: 0.50
#
# #################### Train ####################
# Epoch 179, Loss: 51.0277 +/- 13.6665, Time: 2.48
# ********** Validate **********
# Epoch 179, Loss: 52.7896 +/- 14.9841, Time: 0.52
#
# #################### Train ####################
# Epoch 180, Loss: 50.2064 +/- 14.1639, Time: 2.43
# ********** Validate **********
# Epoch 180, Loss: 52.3597 +/- 15.4389, Time: 0.70
#
# #################### Train ####################
# Epoch 181, Loss: 50.2288 +/- 14.8146, Time: 3.24
# ********** Validate **********
# Epoch 181, Loss: 52.0882 +/- 14.8867, Time: 0.50
#
# #################### Train ####################
# Epoch 182, Loss: 50.1020 +/- 13.5728, Time: 2.42
# ********** Validate **********
# Epoch 182, Loss: 52.0596 +/- 15.0153, Time: 0.48
#
# #################### Train ####################
# Epoch 183, Loss: 50.3977 +/- 13.8707, Time: 2.55
# ********** Validate **********
# Epoch 183, Loss: 51.6611 +/- 15.3484, Time: 0.49
#
# #################### Train ####################
# Epoch 184, Loss: 50.1763 +/- 13.7563, Time: 2.47
# ********** Validate **********
# Epoch 184, Loss: 52.3490 +/- 14.8841, Time: 0.51
#
# #################### Train ####################
# Epoch 185, Loss: 50.0410 +/- 14.2434, Time: 3.30
# ********** Validate **********
# Epoch 185, Loss: 51.3880 +/- 15.3963, Time: 0.57
#
# #################### Train ####################
# Epoch 186, Loss: 50.2999 +/- 14.4211, Time: 2.41
# ********** Validate **********
# Epoch 186, Loss: 51.0218 +/- 15.0646, Time: 0.52
#
# #################### Train ####################
# Epoch 187, Loss: 50.4480 +/- 13.8757, Time: 2.40
# ********** Validate **********
# Epoch 187, Loss: 50.7318 +/- 15.1309, Time: 0.46
#
# #################### Train ####################
# Epoch 188, Loss: 50.5607 +/- 13.8693, Time: 2.44
# ********** Validate **********
# Epoch 188, Loss: 53.9724 +/- 15.3319, Time: 0.49
#
# #################### Train ####################
# Epoch 189, Loss: 50.3330 +/- 13.7743, Time: 2.80
# ********** Validate **********
# Epoch 189, Loss: 51.5413 +/- 15.1229, Time: 0.73
#
# #################### Train ####################
# Epoch 190, Loss: 50.6903 +/- 14.4160, Time: 2.39
# ********** Validate **********
# Epoch 190, Loss: 52.4524 +/- 15.5760, Time: 0.52
#
# #################### Train ####################
# Epoch 191, Loss: 50.3109 +/- 14.0856, Time: 2.47
# ********** Validate **********
# Epoch 191, Loss: 53.5093 +/- 15.2528, Time: 0.50
#
# #################### Train ####################
# Epoch 192, Loss: 51.1254 +/- 13.6507, Time: 2.41
# ********** Validate **********
# Epoch 192, Loss: 50.9527 +/- 15.1918, Time: 0.48
#
# #################### Train ####################
# Epoch 193, Loss: 50.9512 +/- 13.5417, Time: 2.80
# ********** Validate **********
# Epoch 193, Loss: 53.9182 +/- 15.7459, Time: 0.79
#
# #################### Train ####################
# Epoch 194, Loss: 50.4173 +/- 13.2531, Time: 2.55
# ********** Validate **********
# Epoch 194, Loss: 51.3725 +/- 15.5085, Time: 0.48
#
# #################### Train ####################
# Epoch 195, Loss: 51.6116 +/- 14.2755, Time: 2.40
# ********** Validate **********
# Epoch 195, Loss: 55.4740 +/- 15.5204, Time: 0.49
#
# #################### Train ####################
# Epoch 196, Loss: 51.5259 +/- 13.9826, Time: 2.37
# ********** Validate **********
# Epoch 196, Loss: 51.1176 +/- 15.3249, Time: 0.47
#
# #################### Train ####################
# Epoch 197, Loss: 50.6409 +/- 13.4484, Time: 2.56
# ********** Validate **********
# Epoch 197, Loss: 52.5623 +/- 15.6251, Time: 0.71
#
# #################### Train ####################
# Epoch 198, Loss: 50.3166 +/- 14.0566, Time: 3.00
# ********** Validate **********
# Epoch 198, Loss: 51.8026 +/- 15.2463, Time: 0.50
#
# #################### Train ####################
# Epoch 199, Loss: 49.8729 +/- 14.0243, Time: 2.33
# ********** Validate **********
# Epoch 199, Loss: 51.3244 +/- 15.1217, Time: 0.47

# %%
Xtest = torch.stack([tup[0] for tup in test_set])
Xtest = Xtest.to(args['device'])

ytest = torch.stack([tup[1] for tup in test_set])
ypred = net(Xtest).cpu().data

data = torch.cat((ytest, ypred), axis=1)

df_results = pd.DataFrame(data, columns=['ypred', 'ytest'])
df_results.head(20)
# Out:
#     ypred       ytest
# 0   352.0  338.826721
# 1   156.0  149.845932
# 2    12.0    7.161270
# 3     2.0   51.725479
# 4   391.0  362.278320
# 5   391.0  376.722900
# 6    84.0  185.501144
# 7   487.0  622.083435
# 8   176.0  298.425537
# 9   157.0  118.781517
# 10   82.0   91.128403
# 11  186.0  192.564621
# 12  277.0  279.052185
# 13  264.0  371.726135
# 14  312.0  301.320374
# 15   56.0   41.490715
# 16  370.0  116.896187
# 17   14.0   99.957581
# 18  124.0  209.168015
# 19  427.0  433.374878

# %% [markdown]
# # Gráfico de convergência

# %%
plt.figure(figsize=(20, 9))
plt.plot(train_losses, label='Train')
plt.plot(test_losses, label='Test', linewidth=3, alpha=0.5)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Convergence', fontsize=16)
plt.legend()
plt.show()
